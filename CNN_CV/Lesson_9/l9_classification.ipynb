# %% [markdown]
# ### 分类类型：
#
# 1. 二分类
# 2. 多分类
# 3. 多标签分类：可以看成n次的二分类
# 4. 多任务分类
#
# #### 分类：
# 1. input图片——output高度抽象的符号（高维张量）
# 2. 分类问题用经典数据集来验证理论算法
# 3. 数据中只有关于标签的数据

# %% [markdown]
# ### 二分类
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
多分类

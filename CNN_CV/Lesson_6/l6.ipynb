# %% [markdown]
# # CNN 概述
#
# 1，深度：有多少个隐藏层
# 2，宽度：每一层中有多少个神经元
# 3，对于图片一般不用所有像素点作为输入，一般先找特征点
#
# 1，像素分割 segmentation（语义， 实例）
# 2，检测问题，分类并且定位
#
# cnn优势：
# 1，端到端，中间不用管
# 2，模块化，可以不断累加
# 3，解释性比较差（黑箱）
#
# ### 卷积的本质就是特征
# 把特征映射到一个物体上，特征加以组合
#
# ### CNN模块
# 1，数据层、模型、loss
# 2，模型有两个阶段：训练阶段、预测阶段

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### reLU
#
# 下面是导数
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### sigmoid
#
# 1，会有梯度消失情况
# ![image.png](attachment:image.png)

# %% [markdown]
# 解决reLU死亡问题：小于0不可导
# 1，好处：防止过拟合、计算花销更小
# 2，坏处：欠拟合

# %% [markdown]
# 池化：（k=2，s=2步长）  类似滤波
# 1，分成n个池子，每个池子去一个值，图片变小
# 2，这个值取最大值或者是平均值，最大值：对应位置取1，平均值，所有值乘1/4
# 3，池化目标：获取到空间邻域，特征更稳定，降采样，去噪音（弥补计算力不足）
